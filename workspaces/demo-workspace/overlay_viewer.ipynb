# %%
import ast
import cv2
import matplotlib.patches as patches
import matplotlib.pyplot as plt
import numpy as np
import os

# %%
cap = cv2.VideoCapture('cropped_video.mp4')
if not cap.isOpened():
    raise ValueError('unable to open video, please check file path and type')
ret, frame = cap.read()

# %%
plt.imshow(frame)

# %%
with open('frame_data.txt', mode='r') as rf:
    first_line = rf.readline()
rf.close()

# %%
data = ast.literal_eval(first_line)

# %%
rectangles = []
for loc in data:
    x,y = loc[0]
    frame[x][y] = np.asarray([255,0,0])
    rx, ry = loc[1][0], loc[1][1]
    width, height = ry - loc[1][3], rx - loc[1][2]
#     rect = patches.Rectangle((rx,ry),width,height,linewidth=1,edgecolor='g',facecolor='none')
#     rectangles.append(rect)

# %%
f, ax = plt.subplots(figsize=(10,10))
ax.imshow(frame)
# for rect in rectangles:
#     ax.add_patch(rect)
plt.show()
